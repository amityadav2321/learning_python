# %%
import unittest
def add(a,b):
  return a+b

def divide(a,b):
  if b==0:
    raise ValueError("cannot divide by zero")
  return a/b

def is_Palindrome(text):
  cleaned=text.lower().replace(" ","")
  return cleaned==cleaned[::-1]

# %%
class TestMathFunctions(unittest.TestCase):

    def test_add_positive_number(self):
        self.assertEqual(add(2,3),5)

    def test_add_negative_number(self):
        self.assertEqual(add(-2,-3),-5)

    def test_divide_normal(self):
        self.assertEqual(divide(10,2),5)

    def test_divide_by_zero_raise_error(self):
        with self.assertRaises(ValueError):
            divide(10,0)

    def test_palindrome_true(self):
        self.assertTrue(is_Palindrome("madam"))
        self.assertTrue(is_Palindrome("nurses run"))

    def test_palindrome_false(self):
        self.assertFalse(is_Palindrome("python"))
        self.assertFalse(is_Palindrome("Amit Yadav"))



obj = TestMathFunctions()


obj.test_add_positive_number()
print("test_add_positive_number Passed")

obj.test_add_negative_number()
print("test_add_negative_number Passed")

obj.test_divide_normal()
print("test_divide_normal Passed")

obj.test_divide_by_zero_raise_error()
print("test_divide_by_zero_raise_error Passed")

obj.test_palindrome_true()
print("test_palindrome_true Passed")

obj.test_palindrome_false()
print("test_palindrome_false Passed")
# Out:
# test_add_positive_number Passed
# test_add_negative_number Passed
# test_divide_normal Passed
# test_divide_by_zero_raise_error Passed
# test_palindrome_true Passed
# test_palindrome_false Passed
